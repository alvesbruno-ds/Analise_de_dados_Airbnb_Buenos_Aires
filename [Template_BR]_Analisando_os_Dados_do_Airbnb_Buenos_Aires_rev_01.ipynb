# %% [markdown]
# <a href="https://colab.research.google.com/github/alves-bruno-ds/Analise_de_dados_Airbnb_Buenos_Aires/blob/main/%5BTemplate_BR%5D_Analisando_os_Dados_do_Airbnb_Buenos_Aires_rev_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
#
# #### **Data Science na Prática 3.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---
# <img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/C_DADOS.BR%20POSTS.png">
#
#
#
# # Análise dos Dados do Airbnb - *Buenos Aires*
#
# Viajar é uma das melhores experiências que eu conheço. Desde os preparativos até estar efetivamente no destino, tudo é mágico. Se você já escolheu o lugar para passar suas próximas férias e busca alternativas aos hotéis que tal dar uma chance ao [Airbnb](https://www.airbnb.com.br/)?
#
# A plataforma é um sucesso em todo o mundo. **No ano de 2021, com 14 anos de vida, comemorou 1 bilhão de chegadas e mais de US$ 110 bilhões em ganhos para anfitriões.**
#
# Em resumo, Airbnb é uma plataforma para alugar acomodação por temporada e promover experiências únicas.
#
# O nome ‘Airbnb’ vem da junção das palavras em inglês *air* (ar) com a sigla *bnb* (bed and breakfast) – categoria que reúne os estabelecimentos, geralmente residenciais, que oferecem pernoite com café da manhã. Aliás, o primeiro nome da plataforma foi justamente: **Airbed & Breakfast.**
#
#
# Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal [Inside Airbnb](http://insideairbnb.com/get-the-data.html), é possível baixar uma grande quantidade de dados para desenvolver projetos e soluções de *Data Science*.
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
#
# **Neste *notebook*, iremos analisar os dados referentes à cidade de Buenos Aires na Argentina, e ver quais insights podem ser extraídos a partir de dados brutos.**

# %% [markdown]
# ## Parte 00 - Introdução

# %% [markdown]
# ### A Cidade
#
# Buenos Aires é a capital e maior cidade da Argentina, localizada na costa leste do país, na margem do Rio da Prata. Com uma população de cerca de 3 milhões de habitantes, é a segunda maior área metropolitana da América do Sul, atrás apenas da grande São Paulo.
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2001.jpg" width="80%" />
# <figcaption>El Obelisco - Praça da República</figcaption></center>
# </figure>
#
# O clima de Buenos Aires é subtropical, com verões quentes e úmidos e invernos amenos. A temperatura média anual é de cerca de 18°C.
#
# Buenos Aires é um importante centro econômico e cultural da região, com uma economia diversificada que inclui turismo, finanças, tecnologia, comércio e manufatura.
#
# A cultura de Buenos Aires é rica e diversa, com influências europeias, especialmente da Espanha e da Itália, além de elementos indígenas e africanos. A cidade é famosa por sua música, dança, literatura e teatro, especialmente o tango, que surgiu em Buenos Aires no final do século XIX.
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2008.jpg" width="80%" />
# <figcaption>Patrimônio Cultural - Tango</figcaption></center>
# </figure>

# %% [markdown]
# ### Turismo
#
# De acordo com o Conselho Mundial de Viagens, o turismo vem crescendo na capital argentina desde 2002.
#
# A cidade tem mais de 250 parques, a maior concentração está no lado leste da cidade nos bairros de Puerto Madero, Recoleta, Palermo e Belgrano.
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2002.jpg" width="80%" />
# <figcaption>Plaza de Maio</figcaption></center>
# </figure>
#
#
# Alguns dos mais importantes são os Bosques de Palermo, o Jardim Botânico de Buenos Aires, o Jardim Japonês de Buenos Aires, a Plaza San Martín e a Praça de Maio, onde podem ser vistos cinco pontos turísticos importantes: **a Casa Rosada**, sede do governo da Argentina, **o Museu Bicentenário**, a **Catedral Metropolitana de Buenos Aires**, **o Museu Histórico Nacional do Cabildo e da Revolução de Maio** e o **Museu da Administração Federal**.
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2003.jpg" width="80%" />
# <figcaption>Casa Rosada - Sede do governo argentino</figcaption></center>
# </figure>
#
# Buenos Aires tem mais de 280 teatros, mais do que qualquer outra cidade do mundo.Por isso, é declarada "capital mundial do teatro".
#
# Os teatros da cidade mostram tudo, desde musicais a balé, comédia a circos. O mais famoso é o Teatro Colón, classificado como a terceira melhor casa de ópera do mundo pela *National Geographic* e é acusticamente considerada como uma das cinco melhores salas de concertos do mundo.
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2004.jpg" width="80%" />
# <figcaption>Teatro de Colón</figcaption></center>
# </figure>
#
# No bairro de Recoleta se encontra uma grande quantidade de pontos turísticos de grande valor cultural. Ali se pode encontrar a sede principal do Museu Nacional de Belas Artes, a Biblioteca Nacional, o Centro Cultural Recoleta, a Faculdade de Direito da Universidade de Buenos Aires, a Basílica Nossa Senhora de Pilar, o Palais de Glace, o Bar La Biela e o Cemitério da Recoleta, onde se encontram alojados os restos de Eva Duarte de Perón.
#
# No bairro de Retiro pode-se visitar a estação do mesmo nome, e percorrer vários monumentos e edifícios emblemáticos da cidade, como os monumentos aos Caídos na Guerra das Malvinas e ao General San Martín, assim como a Torre Monumental e o Edifício Kavanagh, um dos mais altos da cidade. O Museu de Arte Latino-americano de Buenos Aires, um dos mais importantes do país, se encontra no bairro de Palermo, onde também se situam os Bosques de Palermo, o Planetário, e o Zoológico de Buenos Aires.
#
# A capital tornou-se um destinatário do turismo LGBT. Devido à existência de alguns sites gay-friendly. Ao legalizar o casamento homossexual em 15 de julho de 2010, a Argentina se tornou o primeiro país da América Latina, o segundo nas Américas e o décimo no mundo a fazê-lo.
#
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2005.jpg" width="80%" />
# <figcaption>Referência LGBT - Praça da República</figcaption></center>
# </figure>
#
# A Lei de Identidade de Gênero, aprovada em 2012, tornou o país o único que permite que as pessoas mudem suas identidades de gênero sem enfrentar barreiras como terapia hormonal, cirurgia ou diagnóstico psiquiátrico que as rotula como tendo uma anormalidade. Em 2015, a Organização Mundial da Saúde citou a Argentina como um exemplo em direitos de transgêneros.

# %% [markdown]
# ### Mobilidade Urbana
#
# O sistema de transporte público de Buenos Aires é amplo e variado, oferecendo aos viajantes uma série de opções para se deslocar pela cidade.
#
# O metrô é uma das opções mais populares e eficientes de transporte público em Buenos Aires. Ele é composto por seis linhas que cobrem grande parte da cidade e oferecem conexões com outras formas de transporte, como ônibus e trens. O metrô opera das 5h às 22h30 nos dias úteis e até meia-noite nos finais de semana e feriados.
#
# Os ônibus também são uma opção popular e são frequentes na cidade. Existem mais de 150 linhas de ônibus que operam em Buenos Aires, cobrindo praticamente todas as áreas da cidade. Algumas das rotas de ônibus mais populares são aquelas que conectam o centro da cidade aos bairros turísticos, como Palermo, Recoleta e San Telmo.
#
# Os táxis também são amplamente disponíveis em Buenos Aires, com mais de 40 mil táxis operando na cidade. Eles são uma opção conveniente e segura, embora possam ser um pouco mais caros do que outros meios de transporte público.
#
# Além disso, Buenos Aires tem um sistema de bicicletas compartilhadas chamado Ecobici, que permite aos usuários alugar bicicletas em várias estações pela cidade. Isso pode ser uma ótima opção para explorar bairros como Palermo e Puerto Madero, que têm ciclovias dedicadas.
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2006.jpg" width="80%" />
# <figcaption>Serviço de bicicleta compartilhada - Ecobici</figcaption></center>
# </figure>
#
# Em geral, o sistema de transporte público de Buenos Aires é bem desenvolvido e oferece opções convenientes e acessíveis para se deslocar pela cidade. Os viajantes devem estar atentos aos horários de operação e ao uso de bilhetes ou cartões para pagar pelas viagens.

# %% [markdown]
# ### Airbnb em Buenos Aires
#
# <figure>
# <center>
# <img src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/Buenos%20Aires%2007.jpg" width="80%" />
# <figcaption>Airbnb Logo</figcaption></center>
# </figure>
#
#
# O serviço do Airbnb em Buenos Aires é bastante popular, especialmente entre os viajantes que procuram uma experiência de hospedagem mais autêntica e local.
#
# A cidade tem uma grande variedade de opções de aluguel por meio do Airbnb, incluindo apartamentos, casas e quartos em casas particulares. Essas opções de aluguel muitas vezes são mais baratas do que os hotéis, além de oferecerem aos viajantes a chance de viver como um local e explorar bairros que podem ser menos turísticos.
#
# O Airbnb também oferece uma variedade de experiências, onde os viajantes podem reservar atividades exclusivas, como aulas de tango, visitas a mercados locais ou passeios de bicicleta pela cidade, guiados por moradores locais.
#
# No entanto, é importante lembrar que o aluguel de curto prazo de apartamentos em Buenos Aires é regulamentado pelo governo da cidade e requer que os proprietários sejam registrados e licenciados. Alguns bairros também têm regras específicas para o aluguel de curto prazo, como limites de dias ou restrições de localização. Portanto, é importante verificar a legalidade da locação antes de fazer uma reserva no Airbnb em Buenos Aires.

# %% [markdown]
# ## Parte 01 - Obtenção dos Dados
# A primeira coisa a se fazer é importar as bibliotecas que iremos utilizar no estudo, e logo em seguida o conjunto de dados (arquivo.csv) para o nosso Dataframe.

# %%
# importar os pacotes necessarios
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv("https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/buenos_aires.csv")

# %% [markdown]
# Para este estudo, importamos as seguintes bibliotecas: Pandas, Seaborn,
# e Matplotlib. Sendo que, para esta útima, determinamos a função 'inline' para que seja plotado o gráfico direto em nosso notebook e não em outra janela separada.
#
#
# ---

# %% [markdown]
# ## Parte 02 - Análise dos Dados
# Para iniciar a análise dos dados, é importante que a gente conheça o Dataset e nos familiarize com as variáveis, catalogando e identificando cada uma delas em um dicionário. Para entender o que cada uma significa, consultamos o portal do [Inside Airbnb](http://insideairbnb.com/get-the-data.html).

# %%
# Verificando as dimensões do Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20085 entries, 0 to 20084
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20085 non-null  int64
#  1   name                            20082 non-null  object
#  2   host_id                         20085 non-null  int64
#  3   host_name                       20085 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   20085 non-null  object
#  6   latitude                        20085 non-null  float64
#  7   longitude                       20085 non-null  float64
#  8   room_type                       20085 non-null  object
#  9   price                           20085 non-null  int64
#  10  minimum_nights                  20085 non-null  int64
#  11  number_of_reviews               20085 non-null  int64
# ...

# %% [markdown]
# **Dicionário das variáveis**
#
# * id - número de identificação do anúncio
# * name - nome da propriedade com uma breve descrição
# * host_id - código de identificação do anfitrião
# * host_name - nome do anfitrião
# * neighbourhood_group - coluna sem dados válidos
# * neighbourhood - nome do bairro onde se encontra o imóvel
# * latitude - coordenada latitude (localização geográfica)
# * longitude - coordenada longitude (localização geográfica)
# * room_type - tipo de acomodação
# * price - valor da diária
# * minimum_nights - quantidade mínima de noites que o imóvel pode ser locado
# * number_of_reviews - quantidade de opiniões/recomendação que a propriedade recebeu
# * last_review - data da última opinião/recomendação que o imóvel recebeu
# * reviews_per_month - quantidade de opiniões/recomendações por mês
# * calculated_host_listings_count - quantidade de imóveis que o anfitrião em questão tem cadastrado no Airbnb
# * availability_365 - quantidade de dias que o imóvel está disponível nos próximos 365 dias
# * number_of_reviews_ltm - quantidade de opiniões/recomendações nos últimos 12 meses
# * license - coluna com poucas informações relevantes (97% de valores ausentes). Vamos considerar como "sem valores válidos"

# %%
# mostrar as 5 primeiras entradas
df.head()
# Out:
#        id                                          name   host_id host_name  \
# 0   11508            Amazing Luxurious Apt-Palermo Soho     42762   Candela
# 1   14222  RELAX IN HAPPY HOUSE - PALERMO, BUENOS AIRES  87710233     María
# 2  317484                   Single Room in Palermo Soho   1621752      Luba
# 3   15074                         ROOM WITH RIVER SIGHT     59338    Monica
# 4  118070         Amazing view - GREAT Studio - Balcony    530261   Luciano
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN       Palermo -34.58184  -58.42415  Entire home/apt
# 1                  NaN       Palermo -34.58617  -58.41036  Entire home/apt
# 2                  NaN       Palermo -34.58992  -58.42236     Private room
# 3                  NaN         Nuñez -34.53892  -58.46599     Private room
# 4                  NaN       Palermo -34.58311  -58.42767  Entire home/apt
#
# ...

# %%
# mostrar as 5 últimas entradas
df.tail()
# Out:
#                        id                                             name  \
# 20080  789876010794026163                   Mono ambiente vista panorámica
# 20081  791445322793116711                    Departamento recoleta amplio.
# 20082  789883094728711215                              Palermo Ápt bohemia
# 20083  789886886364996844  Departamento en Congreso de Buenos Aires + coch
# 20084  789889818985355570                           Dulce hogar Belgrano R
#
#          host_id host_name  neighbourhood_group neighbourhood   latitude  \
# 20080  161559109      Juan                  NaN     Caballito -34.608729
# 20081  154496179    Ramiro                  NaN      Recoleta -34.590495
# 20082   60115955     Hache                  NaN       Palermo -34.584193
# 20083  119161621    Camila                  NaN     Monserrat -34.610114
# 20084   48005753  Federico                  NaN      Belgrano -34.561013
#
# ...

# %% [markdown]
# ### **Questão 01 -  Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**

# %%
# identificar o volume de dados do DataFrame
print("Entradas:\t{}".format(df.shape[0]))
print("Variáveis:\t{}\n".format(df.shape[1]))
# Out:
# Entradas:	20085
# Variáveis:	18

# %%
display(df.dtypes)
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# Observamos que o Dataset possui 18 colunas (entradas) e 20.085 variáveis (linhas).
# Em relação ao tipo das variáveis temos os 03 formatos: Números inteiros, Texto e Números fracionários (pontos flutuantes)

# %% [markdown]
# ### **Questão 02 -  Qual a porcentagem de valores ausentes no *dataset*?**
# É importante sabermos a quantidade de valores ausentes e onde eles se encontram para verificarmos qual decisão tomar em relação a eles. Se a quantidade de valores ausentes for insignificante em relação a quantidade de dados e o próposito do estudo, podemos excluí-los. Caso contrário, é necessário tratá-los e substituir as células ausentes com valores relevantes , como por exemplo a média dos valores ou o valor mais recorrente.

# %%
# Quantidade de valores ausentes por entrada
(df.isnull().sum()).sort_values(ascending=False)
# Out:
# neighbourhood_group               20085
# license                           19672
# reviews_per_month                  3831
# last_review                        3831
# name                                  3
# minimum_nights                        0
# number_of_reviews_ltm                 0
# availability_365                      0
# calculated_host_listings_count        0
# number_of_reviews                     0
# id                                    0
# room_type                             0
# longitude                             0
# latitude                              0
# neighbourhood                         0
# host_name                             0
# host_id                               0
# price                                 0
# dtype: int64

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum() / df.shape[0]). sort_values (ascending=False)
# Out:
# neighbourhood_group               1.000000
# license                           0.979437
# reviews_per_month                 0.190739
# last_review                       0.190739
# name                              0.000149
# minimum_nights                    0.000000
# number_of_reviews_ltm             0.000000
# availability_365                  0.000000
# calculated_host_listings_count    0.000000
# number_of_reviews                 0.000000
# id                                0.000000
# room_type                         0.000000
# longitude                         0.000000
# latitude                          0.000000
# neighbourhood                     0.000000
# host_name                         0.000000
# host_id                           0.000000
# price                             0.000000
# dtype: float64

# %% [markdown]
# #### **Qual decisão tomada em relação aos dados ausentes?**
#
# As entradas *`neighbourhood_group`* e *`license`* são toda e/ou em sua maioria constituídas por valores ausentes, ou seja, elas não serão relevantes para o nosso estudo. Vamos **excluir** essas entradas.
#
# As entradas *`reviews_per_month`* e *`last_review`* , tem valores nulos quando a coluna *`number_of_reviews`* é zero. Vamos substituir os dados ausentes por **zero**. Em todo caso, para este estudo, poderíamos excluir também essas colunas, pois não estamos interessados em saber a qualidade das acomodações, baseadas nos comentários, nem tampouco a quantidade de comentários que cada propriedade tem.
#
# Já a entrada *`name`*, possui uma quantidade muito pequena de valores ausentes (3 variáveis). Para esta entrada, vamos **excluir** apenas as 03 linhas que contém esses valores ausentes.
#
# As demais entradas não posssuem nenhum valor ausente.

# %%
# Excluir colunas com dados faltantes
df.drop(columns=['neighbourhood_group', 'license'], inplace=True)

# %%
# Substituir as entradas nulas por zero
df['reviews_per_month'] = df['reviews_per_month']. fillna (0)
df['last_review'] = df['last_review']. fillna (0)

# %%
# Excluir as linhas da entrada 'name' que possui valor ausente
df.dropna(subset=['name'], axis=0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20082 entries, 0 to 20084
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20082 non-null  int64
#  1   name                            20082 non-null  object
#  2   host_id                         20082 non-null  int64
#  3   host_name                       20082 non-null  object
#  4   neighbourhood                   20082 non-null  object
#  5   latitude                        20082 non-null  float64
#  6   longitude                       20082 non-null  float64
#  7   room_type                       20082 non-null  object
#  8   price                           20082 non-null  int64
#  9   minimum_nights                  20082 non-null  int64
#  10  number_of_reviews               20082 non-null  int64
#  11  last_review                     20082 non-null  object
# ...

# %%
# Verificar se ainda restam mais valores ausentes
(df.isnull().sum()).sort_values(ascending=False)
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %% [markdown]
# Pronto! Não temos mais nenhum dado ausente.

# %% [markdown]
# ### **Questão 03 -  Qual o tipo de distribuição das variáveis?**
#
# Para ter um *overview* de como as varáveis estão distribuídas (ver o *range*  e os *outliers*), plotamos o histograma de cada entrada individualmente.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins=15, figsize=(15,10));

# %% [markdown]
# ### **Questão 04 - Qual o tipo de distribuição das variáveis?**
#
# Olhando a disposição dos gráficos, podemos suspeitar da presença de outliers (valores discrepantes ou fora de contexto). Por exemplo, analisando o gráfico da entrada *`price`*, ele mostra um aglomerado de dados em uma região do gráfico, e o restante , sem informação alguma. Muito provavelmente tem uma ou algumas entradas que destoam das demais, por exemplo: 95% dos dados podem estar entre 100 e 1.000,00 pesos. Já 5% acima de 100.000 pesos. Parece algo irreal, mas não podemos duvidar da possibilidade agora.
#
# Vamos testar dois métodos para confirmar a hipótese da presença de *oultliers*
#
# * Resumo estatístico por meio do método **describe ()**
# * Plotar *boxplots* para a variável
#
# Vamos analisar as seguintes entradas:
# *`price` , `minimum_nights` , `number_of_reviews` , `reviews_per_month` ,`calculated_host_listings_count`*

# %%
# Resumo estatístico das variáveis pelo método describe ()
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count']].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  2.008500e+04    20085.000000       20085.000000       20085.000000
# mean   1.644369e+04        7.208564          21.916604           1.063111
# std    1.915379e+05       28.313061          38.478268           1.298486
# min    2.600000e+02        1.000000           0.000000           0.000000
# 25%    5.638000e+03        2.000000           1.000000           0.080000
# 50%    7.953000e+03        3.000000           8.000000           0.600000
# 75%    1.233400e+04        5.000000          25.000000           1.580000
# max    1.744311e+07     1000.000000         612.000000          12.170000
#
#        calculated_host_listings_count
# count                    20085.000000
# mean                        13.073189
# std                         26.460109
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# ...

# %% [markdown]
# Algumas considerações:
#
# * A variável *`price`* tem um valor mínimo de 260 pesos, valor médio de 7.953 pesos e valor máximo de 17.443.110,00 pesos. Com certeza há *outliers*;
#
# * A quantidade mínima de noites *`minimum_nights`* tem um  valor máximo muito alto (1.000 dias). DIficilmente alguém colocaria uma condição dessas para alugar um imóvel no Airbnb.Com certeza temos *outliers*;
#
# * Tem algum imóvel com mais de 100x mais recomendação que a média (*number_of_reviews*); A discrepância também se dá na variável (*review_per_month*);
#
# * 75% dos anfitriões tem em média 10 imóveis disponivéis, porém o valor máximo é 135 imóveis (neste caso, consultando as informações do site, não é um outlier, pois há várias pessoas que possuem entre 20 e 100 imóveis);
#
# Para este estudo, vamos focar em 02 variáveis apenas : *`price`* e *`minimum_nights`*

# %% [markdown]
# #### **Limpando os Outliers**
#
# Após verificar o resumo estatístico e os histogramas acima, já sabemos da presença dos *outliers*. Para tratar esse dados, vamos definir os limites mínimos e máximos utilizando a regra do *IQR Score*
#
# Primeiramente, vamos lembrar o que é o IQR.
#
# O IQR é calculado subtraindo o Terceiro Quartil (75%) pelo Primeiro Quartil (25%).
#
# IQR = Q3 - Q1
#
# Então, os próximos passos são:
#
# * Definir o Q1 e Q3 para as variáveis que serão limpas.
# * Calcular o IQR para as variáveis.
# * Definir o limite superior e inferior para cortar os outliers.
# * Remover os outliers.

# %% [markdown]
# #### Identificação de *Outliers* na para a variável *`price`*

# %%
# identificando os outliers para a variável price
q1_price = df.price.quantile(.25)
q3_price = df.price.quantile(.75)
IQR_price = q3_price - q1_price
print('IQR da variável price: ', IQR_price)

# definindo os limites                                       
sup_price = q3_price + 1.5 * IQR_price
inf_price = q1_price - 1.5 * IQR_price

print('Limite superior de price: ', sup_price)
print('Limite inferior de price: ', inf_price)
# Out:
# IQR da variável price:  6696.0
# Limite superior de price:  22378.0
# Limite inferior de price:  -4406.0

# %% [markdown]
# #### Plotar um gráfico de **Boxplot** para visualizar a limpeza da variável *`price`*

# %%
# verificando o conjunto original
fig, ax = plt.subplots(figsize=(15,3))
df.price.plot(kind='box', vert=False);
ax.set_title('Dataset Original - price')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 22378".format(len(df[df.price > 22378])))
print("Representam {:.2f}% do dataset".format((len(df[df.price > 22378]) / df.shape[0])*100))
# Out:
# O dataset possui 20082 colunas
# 1585 Entradas acima de 22378
# Representam 7.89% do dataset

# %% [markdown]
# #### Identificação de *Outliers* na para a variável *`minumum_nights`*

# %%
# identificando os outliers para a variável minimum_nights
q1_minimum_nights = df.minimum_nights.quantile(.25)
q3_minimum_nights = df.minimum_nights.quantile(.75)
IQR_minimum_nights = q3_minimum_nights - q1_minimum_nights
print('IQR da variável minimum_nights: ', IQR_minimum_nights)

# definindo os limites                                       
sup_minimum_nights = q3_minimum_nights + 1.5 * IQR_minimum_nights
inf_minimum_nights = q1_minimum_nights - 1.5 * IQR_minimum_nights

print('Limite superior de minimum_nights: ', sup_minimum_nights)
print('Limite inferior de minimum_nights: ', inf_minimum_nights)
# Out:
# IQR da variável minimum_nights:  3.0
# Limite superior de minimum_nights:  9.5
# Limite inferior de minimum_nights:  -2.5

# %% [markdown]
# #### Plotar um gráfico de **Boxplot** para visualizar a limpeza da variável *`minimum_nights`*

# %%
# verificando o conjunto original
fig, ax = plt.subplots(figsize=(15,3))
df.minimum_nights.plot(kind='box', vert=False);
ax.set_title('Dataset Original - minimum_nights')
plt.show()
print("O dataset possui {} colunas".format(df.shape[0]))
print("{} Entradas acima de 9.5".format(len(df[df.minimum_nights > 9.5])))
print("Representam {:.2f}% do dataset".format((len(df[df.minimum_nights > 9.5]) / df.shape[0])*100))
# Out:
# O dataset possui 20082 colunas
# 2268 Entradas acima de 9.5
# Representam 11.29% do dataset

# %% [markdown]
# ### **Questão 05 - Eliminando os Outliers**

# %%
# Limpando o Dataset
df_clean = df.copy()

df_clean.drop(df_clean[df_clean.price > 22738].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.price == 0.0].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > 9.5].index, axis=0, inplace=True)

print('Shape antes da limpeza: ', df.shape)
print('Shape após a limpeza: ',df_clean.shape)
# Out:
# Shape antes da limpeza:  (20082, 16)
# Shape após a limpeza:  (16434, 16)

# %% [markdown]
# #### Plotar um gráfico **Boxplot** do conjunto limpo

# %%
# verificando o conjunto limpo
fig, ax = plt.subplots(figsize=(15,3))
df_clean.price.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - price')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df.shape[0]))
# Out:
# Tamanho original: 20082 colunas
# Tamanho atual: 20082 colunas

# %%
# verificando o conjunto limpo
fig, ax = plt.subplots(figsize=(15,3))
df_clean.minimum_nights.plot(kind='box', vert=False);
ax.set_title('Dataset Limpo - minimum_nights')
plt.show()
print("Tamanho original: {} colunas".format(df.shape[0]))
print("Tamanho atual: {} colunas".format(df.shape[0]))
# Out:
# Tamanho original: 20082 colunas
# Tamanho atual: 20082 colunas

# %% [markdown]
# #### Plotagem do histograma após a limpeza dos dados

# %%
# plotar o histograma para as variáveis numéricas
df_clean.hist(figsize=(20,15), grid=False);

# %% [markdown]
# ### **Questão 06 - Qual a média dos preços de aluguel?**

# %%
# ver a média da coluna `price``
df_clean.price.mean()
# Out:
# 8756.966715346234

# %% [markdown]
# Ao eliminarmos os valores que estavam um pouco fora da média da coluna *price*, percebemos que a média de valores diminuiu, ou seja, ficou mais coerente em relação a quantidade de entradas. Os valores considerados como *outliers* "puxam" a média para cima, distorcendo os resultados.

# %% [markdown]
# ### **Questão 07 - Qual a correlação existente entre as variáveis**
#
# Para medir a correlação entre duas variáveis, que nada mais é o quanto uma variável influencia no aumento ou diminuição do valor de um outra, ou ainda, o quão semelhantes elas podem se apresentar, utilizaremo-nos de dois métodos:
#
# * Matriz de correlação
# * Geração de *headmap* a partir dessa matriz, usando a biblioteca **seaborn**

# %%
# criar uma matriz de correlação
corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count']].corr()



# mostrar a matriz de correlação
display(corr)
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.004283          -0.032921
# minimum_nights                 -0.004283        1.000000          -0.079369
# number_of_reviews              -0.032921       -0.079369           1.000000
# reviews_per_month              -0.033091       -0.249655           0.320133
# calculated_host_listings_count  0.163754       -0.062990          -0.048712
#
#                                 reviews_per_month  \
# price                                   -0.033091
# minimum_nights                          -0.249655
# number_of_reviews                        0.320133
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.058146
#
#                                 calculated_host_listings_count
# price                                                 0.163754
# minimum_nights                                       -0.062990
# ...

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# Como exemplo de correlação entre as variáveis podemos citar que:
#
# * O preço da diária não tem nenhuma relação com a quantidade mínima de noites reservada;
# * O quantidade de reviews por mês impacta a quantidade total de reviews da propriedade (óbvio);
#
# ---
# *Porém, no geral, podemos observar que tais correlações não são tão significativas, percebendo o grau de cada uma, no gráfico.*

# %% [markdown]
# ### **Questão 08 - Qual o tipo de imóvel mais alugado no Airbnb?**
# Para esta análise utilzamos o Dataframe original, antes da limpeza. (Para ter certeza de que consideramos todas as variáveis, inclusive as discrepantes).

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df.room_type.value_counts()
# Out:
# Entire home/apt    17820
# Private room        1996
# Shared room          160
# Hotel room           106
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
df.room_type.value_counts() / df.shape[0]*100
# Out:
# Entire home/apt    88.736182
# Private room        9.939249
# Shared room         0.796733
# Hotel room          0.527836
# Name: room_type, dtype: float64

# %% [markdown]
# Em resumo:
#
# * 89% das acomodações são apartamemtos inteiros;
# * 10% são quartos privativos;
# * 1% estão divididos em quartos de hotel e quartos compartilhados;

# %% [markdown]
# ### **Questão 09 - Qual a localidade mais cara do dataset?**

# %%
# ver preços por bairros, na média
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# neighbourhood
# Puerto Madero      15408.064748
# Palermo            10004.422141
# Velez Sarsfield     9801.875000
# Belgrano            9124.812189
# Recoleta            9078.493124
# Nuñez               9061.043605
# Retiro              8825.855346
# Villa Devoto        8371.266667
# Colegiales          8221.056300
# Barracas            8121.015625
# Name: price, dtype: float64

# %% [markdown]
# Para confirmar esta constatação dos dados, fizemos uma rápida pesquisa sobre os bairros de Buenos Aires no Google, seguem os *insigths*:
#
# **Puerto Madero** - "...o bairro mais caro da região"
#
# **Palermo** - "O maior bairro da cidade, une casas e prédios residenciais, parques maravilhosos, centros culturais, grande área comercial e os mais incríveis bares, restaurantes e casas de shows em Buenos Aires."
#
# **Velez Sarsfield** - "Um dos bairros mais calmos da cidade, porém com bons acessos a avenidas importantes e a estação *Floresta del Ferrocarril Gral. Sarmiento*"
#
# **Recoleta** - "O luxo de Buenos Aires é Recoleta"
#
# **Belgrano** - "O Belgrano abrange vários enclaves residenciais sofisticados, uma movimentada rua comercial conhecida pelas marcas de grifes argentinas"
#
# ---
# Como podemos observar, os dados são confiáveis e muito prováveis de exprimirem a realidade, já que apresentam valores mais elevados em regiões nobres e estruturadas da cidade.

# %%
# plotar os imóveis pela latitude-longitude
df.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df['price'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# No gráfico, podemos verificar que a grande maioria dos imóveis fica na região costeira, onde estão situados os principais centros.
#
# <img alt="C_DADOS.BR POSTS.png" width="80%" src="https://raw.githubusercontent.com/alves-bruno-ds/data-science-BR/main/mapa_turistico_buenos_aires.jpg">

# %% [markdown]
# ### **Questão 10 - Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %%
# ver a média da coluna `minimum_nights``
df_clean.minimum_nights.mean()
# Out:
# 2.9430449069003286

# %% [markdown]
# Em Buenos Aires, a média, as locações mínimas são de 3 dias, para imóveis no Airbnb.

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Após a análise dos dados disponibilizados, podemos concluir alguns pontos importantes, que podem ser considerados em uma futura procura por hospedagem em Buenos Aires:
#
# * As regiões mais caras para se hospedar são as que ficam mais próximas da costa e do centro, em contrapartida, também são regiões com mais opções de propriedades;
# * Mais da metade das hospedagens são em apartamentos inteiros;
# * 03 é a média de noites de hospedagem;
# * É comum encontrarmos anfitriões que possuem mais de 01 imóvel cadastrados na plataforma. Com isso, é possível conversar e pedir sugestões da propriedade que for mais conveniente para o período de estadia;
# * O valor médio de hospedagem é de 8.800 mil pesos argentinos que, convertendo para a nossa moeda, representa R$ 213,50.
